# %% [markdown]
# # Building Prediction Model

# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN

# %%
df = pd.read_csv('tel_churn.csv')
df.head(3)
# Out:
#    Unnamed: 0  Monthly Charge  Total Charges  Churn Label  Gender_Female  \
# 0           0           39.65          39.65            1          False
# 1           1           80.65         633.30            1           True
# 2           2           95.45        1752.55            1          False
#
#    Gender_Male  Senior Citizen_No  Senior Citizen_Yes  Married_No  \
# 0         True              False                True        True
# 1        False              False                True       False
# 2         True              False                True        True
#
#    Married_Yes  ...  Paperless Billing_Yes  Payment Method_Bank Withdrawal  \
# 0        False  ...                   True                            True
# 1         True  ...                   True                           False
# 2        False  ...                   True                            True
#
#    Payment Method_Credit Card  Payment Method_Mailed Check  \
# 0                       False                        False
# 1                        True                        False
# 2                       False                        False
#
#    Tenure_group_1 - 12  Tenure_group_13 - 12  Tenure_group_25 - 12  \
# 0                 True                 False                 False
# 1                 True                 False                 False
# 2                False                  True                 False
#
#    Tenure_group_37 - 12  Tenure_group_49 - 12  Tenure_group_61 - 12
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
#
# [3 rows x 44 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    Monthly Charge  Total Charges  Churn Label  Gender_Female  Gender_Male  \
# 0           39.65          39.65            1          False         True
# 1           80.65         633.30            1           True        False
# 2           95.45        1752.55            1          False         True
# 3           98.50        2514.50            1           True        False
# 4           76.50        2868.15            1           True        False
#
#    Senior Citizen_No  Senior Citizen_Yes  Married_No  Married_Yes  \
# 0              False                True        True        False
# 1              False                True       False         True
# 2              False                True        True        False
# 3              False                True       False         True
# 4              False                True       False         True
#
#    Dependents_No  ...  Paperless Billing_Yes  Payment Method_Bank Withdrawal  \
# 0           True  ...                   True                            True
# 1          False  ...                   True                           False
# 2          False  ...                   True                            True
# 3          False  ...                   True                            True
# 4          False  ...                   True                            True
#
#    Payment Method_Credit Card  Payment Method_Mailed Check  \
# 0                       False                        False
# 1                        True                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    Tenure_group_1 - 12  Tenure_group_13 - 12  Tenure_group_25 - 12  \
# 0                 True                 False                 False
# 1                 True                 False                 False
# 2                False                  True                 False
# 3                False                 False                  True
# 4                False                 False                 False
#
#    Tenure_group_37 - 12  Tenure_group_49 - 12  Tenure_group_61 - 12
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                  True                 False                 False
#
# [5 rows x 43 columns]

# %%
x = df.drop('Churn Label', axis=1)
x
# Out:
#       Monthly Charge  Total Charges  Gender_Female  Gender_Male  \
# 0              39.65          39.65          False         True
# 1              80.65         633.30           True        False
# 2              95.45        1752.55          False         True
# 3              98.50        2514.50           True        False
# 4              76.50        2868.15           True        False
# ...              ...            ...            ...          ...
# 7038           21.15        1419.40           True        False
# 7039           84.80        1990.50          False         True
# 7040          103.20        7362.90           True        False
# 7041           29.60         346.45           True        False
# 7042          105.65        6844.50          False         True
#
#       Senior Citizen_No  Senior Citizen_Yes  Married_No  Married_Yes  \
# 0                 False                True        True        False
# 1                 False                True       False         True
# 2                 False                True        True        False
# 3                 False                True       False         True
# 4                 False                True       False         True
# ...                 ...                 ...         ...          ...
# 7038               True               False        True        False
# 7039               True               False       False         True
# 7040               True               False       False         True
# 7041               True               False       False         True
# 7042               True               False        True        False
#
#       Dependents_No  Dependents_Yes  ...  Paperless Billing_Yes  \
# 0              True           False  ...                   True
# 1             False            True  ...                   True
# 2             False            True  ...                   True
# 3             False            True  ...                   True
# 4             False            True  ...                   True
# ...             ...             ...  ...                    ...
# 7038           True           False  ...                   True
# 7039          False            True  ...                   True
# 7040          False            True  ...                   True
# 7041          False            True  ...                   True
# 7042           True           False  ...                   True
#
#       Payment Method_Bank Withdrawal  Payment Method_Credit Card  \
# 0                               True                       False
# 1                              False                        True
# 2                               True                       False
# 3                               True                       False
# 4                               True                       False
# ...                              ...                         ...
# 7038                            True                       False
# 7039                           False                       False
# 7040                           False                        True
# 7041                            True                       False
# 7042                            True                       False
#
#       Payment Method_Mailed Check  Tenure_group_1 - 12  Tenure_group_13 - 12  \
# 0                           False                 True                 False
# 1                           False                 True                 False
# 2                           False                False                  True
# 3                           False                False                 False
# 4                           False                False                 False
# ...                           ...                  ...                   ...
# 7038                        False                False                 False
# 7039                         True                False                  True
# 7040                        False                False                 False
# 7041                        False                 True                 False
# 7042                        False                False                 False
#
#       Tenure_group_25 - 12  Tenure_group_37 - 12  Tenure_group_49 - 12  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                 False                 False
# 3                     True                 False                 False
# 4                    False                  True                 False
# ...                    ...                   ...                   ...
# 7038                 False                 False                 False
# 7039                 False                 False                 False
# 7040                 False                 False                 False
# 7041                 False                 False                 False
# 7042                 False                 False                 False
#
#       Tenure_group_61 - 12
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 7038                  True
# 7039                 False
# 7040                  True
# 7041                 False
# 7042                  True
#
# [7043 rows x 42 columns]

# %%
y = df['Churn Label']
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Label, Length: 7043, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Decision Tree classifier

# %%
model_dt = DecisionTreeClassifier(criterion='gini', max_depth=6, min_samples_leaf=8, random_state=100)

# %%
model_dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred = model_dt.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model_dt.score(x_test,y_pred)*100
# Out:
# 100.0

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.88      1009
#            1       0.75      0.49      0.60       400
#
#     accuracy                           0.81      1409
#    macro avg       0.79      0.71      0.74      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[943  66]
#  [202 198]]

# %% [markdown]
# ### Smart Analysis (smoteenn)
# ### Up sampling and down sampling
# ### It use to resample using Smote and cleaning using ENN

# %%
sm = SMOTEENN()
X_resampled, y_resampled = sm.fit_resample(x,y)

# %%
xr_train, xr_test, yr_train, yr_test = train_test_split(X_resampled, y_resampled, test_size=0.2)

# %%
model_dt_smote = DecisionTreeClassifier(criterion='gini', max_depth=6, min_samples_leaf=8)
model_dt_smote.fit(xr_train, yr_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8)

# %%
y_pred_smote = model_dt_smote.predict(xr_test)

# %%
print(classification_report(yr_test, y_pred_smote, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       530
#            1       0.92      0.96      0.94       664
#
#     accuracy                           0.93      1194
#    macro avg       0.93      0.93      0.93      1194
# weighted avg       0.93      0.93      0.93      1194

# %%
print(confusion_matrix(yr_test, y_pred_smote))
# Out:
# [[473  57]
#  [ 27 637]]

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(criterion='gini', max_depth=6, min_samples_leaf=8, n_estimators=100)
model_rf.fit(x_train, y_train)
y_pred_rf = model_rf.predict(x_test)

# %%
print(classification_report(y_test, y_pred_rf, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      1009
#            1       0.73      0.56      0.64       400
#
#     accuracy                           0.82      1409
#    macro avg       0.79      0.74      0.76      1409
# weighted avg       0.81      0.82      0.81      1409

# %%
sm = SMOTEENN()
Xr_resampled, yr_resampled = sm.fit_resample(x,y)
xr_train, xr_test, yr_train, yr_test = train_test_split(Xr_resampled, yr_resampled, test_size=0.2)
model_smote_rf = DecisionTreeClassifier(criterion='gini', max_depth=6, min_samples_leaf=8)
model_smote_rf.fit(xr_train, yr_train)
y_pred_smote_rf = model_smote_rf.predict(xr_test)

# %%
print(classification_report(yr_test, y_pred_smote_rf, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       549
#            1       0.94      0.94      0.94       651
#
#     accuracy                           0.93      1200
#    macro avg       0.93      0.93      0.93      1200
# weighted avg       0.93      0.93      0.93      1200

# %%
print(confusion_matrix(yr_test, y_pred_smote_rf))
# Out:
# [[509  40]
#  [ 40 611]]

# %% [markdown]
# ## How to save the code??
# ## Use pickle to save the code and re use it when needed.

# %% [markdown]
# ## Now run the model and see the score directly

# %%
import pickle
filename = 'model.pkl'
pickle.dump(model_smote_rf, open(filename, 'wb'))

# %%
load_model = pickle.load(open(filename, 'rb'))

# %%
load_model.score(xr_test, yr_test)
# Out:
# 0.9333333333333333
